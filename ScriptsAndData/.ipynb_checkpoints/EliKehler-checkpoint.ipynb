# %%
# Cargar funciones de la librería de python data analysis
import pandas as pd 

# Leer csv con datos y cargar en el dataframe data
data = pd.read_csv("/home/julio/MEGAsync/Documentos/tesis/elizabeth kehler/protestas_denuncias_only_contracts_input_data_scores_iforest_1000_50.csv") 

# Preview de las 5 primeras filas de data 
data.head()
# Out:
#        id                ocid        date  buyer_identifier  \
# 0  317791  112112377189460000  1534572969      1.281000e+09
# 1  308266  285898009090737000  1531698190               NaN
# 2  345395  327543767916472000  1531764511               NaN
# 3  328265  159016963117912000  1534559299      2.551000e+09
# 4  336988  119643571607931000  1531294564               NaN
#
#    buyer_contactPoint_name  buyer_contactPoint_email  buyer_contactPoint_url  \
# 0                      NaN                       NaN                     NaN
# 1             9.403059e+17              3.210374e+17                     NaN
# 2             1.814730e+17              5.713424e+17                     NaN
# 3                      NaN                       NaN                     NaN
# 4             6.055829e+17              2.347393e+17                     NaN
#
#    buyer_contactPoint_telephone  buyer_address_streetAddress  buyer_address  \
# ...

# %%
corMatrix = data.corr()
print(corMatrix[['tender_procuringEntity_memberOf','tender_procuringEntity_identifier']])
# Out:
#                                           tender_procuringEntity_memberOf  \
# id                                                               0.143483
# ocid                                                            -0.034087
# date                                                             0.023764
# buyer_identifier                                                 0.104043
# buyer_contactPoint_name                                               NaN
# buyer_contactPoint_email                                              NaN
# buyer_contactPoint_url                                                NaN
# buyer_contactPoint_telephone                                          NaN
# buyer_address_streetAddress                                           NaN
# buyer_address                                                         NaN
# buyer_memberOf                                                   1.000000
# buyer_roles                                                      0.037148
# ...

# %%
data.describe()['tender_submissionMethod']
# Out:
# count    1762.000000
# mean        1.267877
# std         0.442979
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         2.000000
# Name: tender_submissionMethod, dtype: float64
